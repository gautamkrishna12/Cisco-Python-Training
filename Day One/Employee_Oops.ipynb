# %%
#Using Oops and Menu Deiven approach

# %%
Employees=[]

# %%
class Employee():
    def __init__(self,emp_id,name,department,salary):
        self.Emp_id=emp_id
        self.Name=name
        self.Department=department
        self.Salary=salary

    def Update_Salary(self):
        new_salary=int(input('Enter the new salary'))
        self.Salary=new_salary
        return 'Salary updated successfully'
    
    def Change_Department(self):
        new_dept=input('Enter the new department')
        self.Department=new_dept
        return 'Department updated Successfully'

    def Employee_Details(self):
        print(f'Employee ID : {self.Emp_id}')
        print(f'Name : {self.Name}')
        print(f'Department : {self.Department}')
        print(f'Salary : {self.Salary}')

# %%
def Add_NewEmployee():
    emp_id=int(input('Enter the employee id :'))
    for i in Employees:
        if i.Emp_id==emp_id:
            return f'Employee with employee id {emp_id} already exists'
    name=input('Enter the name :')
    department=input('Enter the department :')
    salary=int(input('Enter salary :'))
    emp=Employee(emp_id,name,department,salary)
    Employees.append(emp)
    print('Employee added successfully.')

# %%
def Search_Employee():
    emp_id=int(input('Enter the employee id :')) 
    for i in Employees:
        if i.Emp_id==emp_id:
            print("\n")
            return i.Employee_Details()
            print("\n")
    
    print(f'Employee with Employee ID {emp_id} not exists.')

# %%
def Remove_Employee():
    emp_id=int(input('Enter the employee id :')) 
    for i in Employees:
        if i.Emp_id==emp_id:
            Employees.pop(Employees.index(i))
            print('Employee is removed successfully')
            del i
            return
    print(f'Employee with Employee ID {emp_id} not exists.')

# %%
def Update_Salary():
    emp_id=int(input('Enter the employee id :')) 
    for i in Employees:
        if i.Emp_id==emp_id:
            new_salary=int(input('Enter the new salary :'))
            i.Salary=new_salary
            print('Salary Updated successfully')
            return
    print(f'Employee with Employee ID {emp_id} not exists.')

# %%
while True:
    print("\n****** Employee Management System ******")
    print("1. Add New Employee")
    print("2. Search Employees")
    print("3. Update Employee Salary")
    print("4. Remove Employee")
    print("5. Exit\n")
    choice=int(input('Enter your Choice: '))

    if choice==1:
        Add_NewEmployee()
    elif choice==2:
        Search_Employee()
    elif choice==3:
        Update_Salary()
    elif choice==4:
        Remove_Employee()
    elif choice==5:
        print("***** Exiting the progra. Thank You ! *****")
        break
    else:
        print('Enter a valid choice.')
# Out:
# ****** Employee Management System ******
# 1. Add New Employee
# 2. Search Employees
# 3. Update Employee Salary
# 4. Remove Employee
# 5. Exit
#
# Salary Updated successfully
#
# ****** Employee Management System ******
# 1. Add New Employee
# 2. Search Employees
# 3. Update Employee Salary
# 4. Remove Employee
# 5. Exit
#
# Employee with Employee ID 3 not exists.
#
# ****** Employee Management System ******
# 1. Add New Employee
# 2. Search Employees
# 3. Update Employee Salary
# 4. Remove Employee
# 5. Exit
#
# Employee with Employee ID 8 not exists.
#
# ****** Employee Management System ******
# 1. Add New Employee
# 2. Search Employees
# 3. Update Employee Salary
# 4. Remove Employee
# 5. Exit
#
# Employee is removed successfully
#
# ****** Employee Management System ******
# 1. Add New Employee
# 2. Search Employees
# 3. Update Employee Salary
# 4. Remove Employee
# 5. Exit
#
# ***** Exiting the progra. Thank You ! *****
